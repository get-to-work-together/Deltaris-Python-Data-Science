# %% [markdown]
# # Demo GeoTIFF
#
# https://www.earthdata.nasa.gov/about/esdis/esco/standards-practices/geotiff
#
# ### RasterIO
# https://towardsdatascience.com/reading-and-visualizing-geotiff-images-with-python-8dcca7a74510/

# %%
import rasterio
from rasterio.plot import show
from rasterio.windows import Window

# %%
# https://visibleearth.nasa.gov/images/57752/blue-marble-land-surface-shallow-water-and-shaded-topography
filename = '../Datasets/land_shallow_topo_2048.tif'

# https://visibleearth.nasa.gov/images/147190/explorer-base-map/147192l
filename = '../Datasets/eo_base_2020_clean_geo.tif'

# https://neo.gsfc.nasa.gov/view.php?datasetId=GEBCO_BATHY
filename = '../Datasets/GEBCO_BATHY_2002-01-01_gs_3600x1800.TIFF'

# https://download.gebco.net
filename = '../Datasets/gebco_2024_n53.399_s53.2327_w5.0309_e5.2299.tif'

img = rasterio.open(filename)

print(img.shape)
show(img)

print(img.width, img.height)
# Out:
# (40, 48)
# 48 40
