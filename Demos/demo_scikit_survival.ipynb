# %% [markdown]
# # Scikit Survival

# %%
from sksurv.linear_model import CoxPHSurvivalAnalysis

# %% [markdown]
# ###  Load lung cancer survival data

# %%
from sksurv.datasets import load_veterans_lung_cancer

X, y = load_veterans_lung_cancer()

# Check the structure
# y contains structured data:
# • event: Whether the event (death) occurred (True/False)
# •	time: Duration until event or censoring

print(y[:5])  # Structured array with event status and survival time
# Out:
# [( True,  72.) ( True, 411.) ( True, 228.) ( True, 126.) ( True, 118.)]

# %%
X.dtypes
# Out:
# Age_in_years              float64
# Celltype                 category
# Karnofsky_score           float64
# Months_from_Diagnosis     float64
# Prior_therapy            category
# Treatment                category
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object','string','category']).columns.tolist()
numerical_cols = X.select_dtypes(exclude=['object','string','category']).columns.tolist()

print("Categorical columns:", categorical_cols)  # Should show ['celltype', 'trt']
print("Numerical columns:", numerical_cols)      # Should show numerical features

# Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numerical_cols),  # Keep numerical features as-is
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)  # Encode categorical features
    ]
)

# Combine preprocessing with Cox model
pipeline = make_pipeline(preprocessor, CoxPHSurvivalAnalysis())

# Fit the model
pipeline.fit(X, y)
# Out:
# Categorical columns: ['Celltype', 'Prior_therapy', 'Treatment']
# Numerical columns: ['Age_in_years', 'Karnofsky_score', 'Months_from_Diagnosis']
# /Users/peter/Computrain/Deltaris - Machine Learning Timeseries/venv/lib/python3.13/site-packages/sksurv/linear_model/coxph.py:449: LinAlgWarning: Ill-conditioned matrix (rcond=3.8131e-21): result may not be accurate.
#   delta = solve(
# /Users/peter/Computrain/Deltaris - Machine Learning Timeseries/venv/lib/python3.13/site-packages/sksurv/linear_model/coxph.py:449: LinAlgWarning: Ill-conditioned matrix (rcond=3.00089e-21): result may not be accurate.
#   delta = solve(
# /Users/peter/Computrain/Deltaris - Machine Learning Timeseries/venv/lib/python3.13/site-packages/sksurv/linear_model/coxph.py:449: LinAlgWarning: Ill-conditioned matrix (rcond=4.6099e-20): result may not be accurate.
#   delta = solve(
# ...

# %%
# Initialize the Cox model
cox_model = CoxPHSurvivalAnalysis()

# Train the model
cox_model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/03/yj771kx92fj0g_3xbr70x6980000gn/T/ipykernel_26255/3207695073.py in ?()
#       1 # Initialize the Cox model
#       2 cox_model = CoxPHSurvivalAnalysis()
#       3
#       4 # Train the model
# ----> 5 cox_model.fit(X, y)
#
# ~/Computrain/Deltaris - Machine Learning Timeseries/venv/lib/python3.13/site-packages/sksurv/linear_model/coxph.py in ?(self, X, y)
#     412         self
#     413         """
#     414         self._validate_params()
#     415
# --> 416         X = self._validate_data(X, ensure_min_samples=2, dtype=np.float64)
#     417         event, time = check_array_survival(X, y)
#     418
#     419         if isinstance(self.alpha, (numbers.Real, numbers.Integral)):
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predict survival function for a sample patient
surv_func = cox_model.predict_survival_function(X.iloc[:1])

# Plot the survival curve
for fn in surv_func:
    plt.step(fn.x, fn.y, where="post")
    
plt.title("Survival Function")
plt.xlabel("Time (Days)")
plt.ylabel("Survival Probability")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 import numpy as np
#       4 # Predict survival function for a sample patient
# ----> 5 surv_func = cox_model.predict_survival_function(X.iloc[:1])
#       7 # Plot the survival curve
#       8 for fn in surv_func:
#
# File ~/Computrain/Deltaris - Machine Learning Timeseries/venv/lib/python3.13/site-packages/sksurv/linear_model/coxph.py:618, in CoxPHSurvivalAnalysis.predict_survival_function(self, X, return_array)
#     560 def predict_survival_function(self, X, return_array=False):
#     561     """Predict survival function.
#     562
#     563     The survival function for an individual
#    (...)
#     616     >>> plt.show()
#     617     """
# --> 618     return self._predict_survival_function(self._baseline_model, self.predict(X), return_array)
#
# ...
